# %%
# hi this is a program

# %%
family_members_relations={
    "family_members":{"jayapaul":"father",
                     "rangasarojini":"mother",
                     "rajakumari":"eldersister",
                     "sunilraju":"brother",
                     "meghana":"sisterilla",
                     "salomi":"sister",
                     "venkataramana":" brotherilla",
                     "venketeswarao":"maternaluncle",
                     "anilkumar":"myhusband",
                     "sowjanya":"myself"
                     },
                     "relations":{
                         "father":"jayapaul",
                         "mother":"rangasarojini",
                         "eldersister":"rajakumari",
                         "brother":"sunilraju",
                         "sisterilla":"meghana",
                         "sister":"salomi",
                         "brotherilla":"venkataramana",
                         "maternaluncle":"venkateswaro",
                         "myhusband":"anilkumar",
                         "myself":"sowjanya"
                         
                     }
    
    
}

# %%
print(family_members_relations)
# Out:
# {'family_members': {'jayapaul': 'father', 'rangasarojini': 'mother', 'rajakumari': 'eldersister', 'sunilraju': 'brother', 'meghana': 'sisterilla', 'salomi': 'sister', 'venkataramana': ' brotherilla', 'venketeswarao': 'maternaluncle', 'anilkumar': 'myhusband', 'sowjanya': 'myself'}, 'relations': {'father': 'jayapaul', 'mother': 'rangasarojini', 'eldersister': 'rajakumari', 'brother': 'sunilraju', 'sisterilla': 'meghana', 'sister': 'salomi', 'brotherilla': 'venkataramana', 'maternaluncle': 'venkateswaro', 'myhusband': 'anilkumar', 'myself': 'sowjanya'}}

# %%
print("my father name is",family_members_relations["relations"]["father"])
# Out:
# my father name is jayapaul

# %%
print("my favourite family member name is",family_members_relations["relations"]["sister"])
# Out:
# my favourite family member name is salomi
