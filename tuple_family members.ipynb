# %%
family_member=("father","mother","elder sister","niece","brother","sister illa","nephew","myself","my husband","sister")

# %%
family_member
# Out:
# ('father',
#  'mother',
#  'elder sister',
#  'niece',
#  'brother',
#  'sister illa',
#  'nephew',
#  'myself',
#  'my husband',
#  'sister')

# %%
family_member[0]
# Out:
# 'father'

# %%
family_member[1]
# Out:
# 'mother'

# %%
family_member[2]
# Out:
# 'elder sister'

# %%
family_member[3]
# Out:
# 'niece'

# %%
family_member[4]
# Out:
# 'brother'

# %%
family_member[5]
# Out:
# 'sister illa'

# %%
family_member[6]
# Out:
# 'nephew'

# %%
family_member[7]
# Out:
# 'myself'

# %%
family_member[8]
# Out:
# 'my husband'

# %%
family_member[9]
# Out:
# 'sister'

# %%
family_member[-1]
# Out:
# 'sister'

# %%
family_member[-2]
# Out:
# 'my husband'

# %%
family_member[-3]
# Out:
# 'myself'

# %%
family_member[-4]
# Out:
# 'nephew'

# %%
family_member[-5]
# Out:
# 'sister illa'

# %%
family_member[-6]
# Out:
# 'brother'

# %%
family_member[-7]
# Out:
# 'niece'

# %%
family_member[-8]
# Out:
# 'elder sister'

# %%
family_member[-9]
# Out:
# 'mother'

# %%
family_member[0]
# Out:
# 'father'

# %%
family_member[0:3]
# Out:
# ('father', 'mother', 'elder sister')

# %%
family_member[1:2]
# Out:
# ('mother',)

# %%
family_member[0:4]
# Out:
# ('father', 'mother', 'elder sister', 'niece')

# %%
family_member[0:-1]
# Out:
# ('father',
#  'mother',
#  'elder sister',
#  'niece',
#  'brother',
#  'sister illa',
#  'nephew',
#  'myself',
#  'my husband')

# %%
family_member[3:-2]
# Out:
# ('niece', 'brother', 'sister illa', 'nephew', 'myself')

# %%
family_member[-3:-2]
# Out:
# ('myself',)

# %%
family_member[5:]
# Out:
# ('sister illa', 'nephew', 'myself', 'my husband', 'sister')

# %%
type(family_member)
# Out:
# dict
