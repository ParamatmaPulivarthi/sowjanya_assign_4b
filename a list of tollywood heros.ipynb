# %%
# this is a list of tollywod heros names program

# %%
tollywood_heros=["chiru","balaya","nag","venky","powerstar","superstar","ntr","ramcharan"]

# %%
tollywood_heros
# Out:
# ['chiru',
#  'balaya',
#  'nag',
#  'venky',
#  'powerstar',
#  'superstar',
#  'ntr',
#  'ramcharan']

# %%
type(tollywood_heros)
# Out:
# list

# %%
tollywood_heros_v1=list(tollywood_heros)

# %%
tollywood_heros_v1
# Out:
# ['chiru',
#  'balaya',
#  'nag',
#  'venky',
#  'powerstar',
#  'superstar',
#  'ntr',
#  'ramcharan']

# %%
tollywood_heros_v1[0]="chiranjivi"

# %%
tollywood_heros_v1[0]
# Out:
# 'chiranjivi'

# %%
tollywood_heros_v1
# Out:
# ['chiranjivi',
#  'balaya',
#  'nag',
#  'venky',
#  'powerstar',
#  'superstar',
#  'ntr',
#  'ramcharan']

# %%
tollywood_heros_v1[1]="balakrishna"

# %%
tollywood_heros_v1[1]
# Out:
# 'balakrishna'

# %%
tollywood_heros_v1[2]="nagrujana"

# %%
tollywood_heros_v1[2]
# Out:
# 'nagrujana'

# %%
tollywood_heros_v1[3]="venkatesh"

# %%
tollywood_heros_v1[3]
# Out:
# 'venkatesh'

# %%
tollywood_heros_v1[4]="pawankalyan"

# %%
tollywood_heros_v1[4]
# Out:
# 'pawankalyan'

# %%
tollywood_heros_v1[5]="maheshbabu"

# %%
tollywood_heros_v1[5]
# Out:
# 'maheshbabu'

# %%
tollywood_heros_v1[6]="NT rama rao"

# %%
tollywood_heros_v1[6]
# Out:
# 'NT rama rao'

# %%
tollywood_heros_v1[7]="ramcharan"

# %%
tollywood_heros_v1[7]
# Out:
# 'ramcharan'

# %%
tollywood_heros_v1
# Out:
# ['chiranjivi',
#  'balakrishna',
#  'nagrujana',
#  'venkatesh',
#  'pawankalyan',
#  'maheshbabu',
#  'NT rama rao',
#  'ramcharan']

# %%
type(tollywood_heros_v1)
# Out:
# list
