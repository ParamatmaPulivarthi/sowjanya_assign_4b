# %%
# hi this a program

# %%
family_members={    
    "jayapaul"     :{"relation":"father",      "qul":"degree","location":"nidumolu"},
    "rangasarojini":{"relation":"mother",      "qul":"degree","location":"nidumolu"},
    "rajakumari"   :{"relation":"eldersister", "qul":"b.tech","location":"vijayawada"},
    "sunil"        :{"relation":"brother",     "qul":"b.tech","location":"nidumolu"},
    "meghana"      :{"relation":"sisterinlaw", "qul":"b.ed",  "location":"nidumolu"},
    "salomi"       :{"realtion":"sister",      "qul":"d.ed",  "location":"nidumolu"},
    "sowjanya"     :{"relation":"myself",      "qul":"b.tech","location":"movva"},
    "anilkumar"    :{"relation":"husband",     "qul":"dipolma","location":"movva"},
    "venkataramana":{"relation":"brotherilla", "qul":"mlt",   "location":"vijayawada"},
    "venkateswarao":{"realtion":"maternaluncle","qul":"7th",  "location":"movva"}
}

# %%
family_members
# Out:
# {'jayapaul': {'relation': 'father', 'qul': 'degree', 'location': 'nidumolu'},
#  'rangasarojini': {'relation': 'mother',
#   'qul': 'degree',
#   'location': 'nidumolu'},
#  'rajakumari': {'relation': 'eldersister',
#   'qul': 'b.tech',
#   'location': 'vijayawada'},
#  'sunil': {'relation': 'brother', 'qul': 'b.tech', 'location': 'nidumolu'},
#  'meghana': {'relation': 'sisterinlaw', 'qul': 'b.ed', 'location': 'nidumolu'},
#  'salomi': {'realtion': 'sister', 'qul': 'd.ed', 'location': 'nidumolu'},
#  'sowjanya': {'relation': 'myself', 'qul': 'b.tech', 'location': 'movva'},
#  'anilkumar': {'relation': 'husband', 'qul': 'dipolma', 'location': 'movva'},
#  'venkataramana': {'relation': 'brotherilla',
#   'qul': 'mlt',
#   'location': 'vijayawada'},
#  'venkateswarao': {'realtion': 'maternaluncle',
#   'qul': '7th',
#   'location': 'movva'}}

# %%
print(family_members)
# Out:
# {'jayapaul': {'relation': 'father', 'qul': 'degree', 'location': 'nidumolu'}, 'rangasarojini': {'relation': 'mother', 'qul': 'degree', 'location': 'nidumolu'}, 'rajakumari': {'relation': 'eldersister', 'qul': 'b.tech', 'location': 'vijayawada'}, 'sunil': {'relation': 'brother', 'qul': 'b.tech', 'location': 'nidumolu'}, 'meghana': {'relation': 'sisterinlaw', 'qul': 'b.ed', 'location': 'nidumolu'}, 'salomi': {'realtion': 'sister', 'qul': 'd.ed', 'location': 'nidumolu'}, 'sowjanya': {'relation': 'myself', 'qul': 'b.tech', 'location': 'movva'}, 'anilkumar': {'relation': 'husband', 'qul': 'dipolma', 'location': 'movva'}, 'venkataramana': {'relation': 'brotherilla', 'qul': 'mlt', 'location': 'vijayawada'}, 'venkateswarao': {'realtion': 'maternaluncle', 'qul': '7th', 'location': 'movva'}}

# %%
type(family_members)
# Out:
# dict
