# %%
food_ratings = {
    "veg_items":{"pizza":5,
                  "dosa":3,
                  "salad":2,
                  "potato":4,
                  "lemonrice":4,
                  "soup":3,
                  "cocountrice":5,
                  "yogurtbasedcurry":1,
                  "pasta":3,
                  "stuffedbirijil":2},
    "nonveg_items":{"chickencurry":2,
                    "fishfry":3,
                    "muttoncurry":4,
                    "prawnscurry":3,
                    "eggfriedrice":3,
                    "chickenfriedrice":2,
                    "crabcurry":4,
                    "chickenpickele":3,
                    "gonguramutton":2,
                    "eggcurry":3}
                   }

# %%
food_ratings
# Out:
# {'veg_items': {'pizza': 5,
#   'dosa': 3,
#   'salad': 2,
#   'potato': 4,
#   'lemonrice': 4,
#   'soup': 3,
#   'cocountrice': 5,
#   'yogurtbasedcurry': 1,
#   'pasta': 3,
#   'stuffedbirijil': 2},
#  'nonveg_items': {'chickencurry': 2,
#   'fishfry': 3,
#   'muttoncurry': 4,
#   'prawnscurry': 3,
#   'eggfriedrice': 3,
#   'chickenfriedrice': 2,
#   'crabcurry': 4,
#   'chickenpickele': 3,
#   'gonguramutton': 2,
#   'eggcurry': 3}}

# %%
rating1="yogurtbasedcurry"

# %%
print("rating1 food item name is",rating1)
# Out:
# rating1 food item name is yogurtbasedcurry
