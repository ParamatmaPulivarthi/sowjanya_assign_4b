# %%
destination_cities_rating={
    "destinations":[
        {"city":"paris","rating":1},
        {"city":"tokyo","rating":2},
        {"city":"london","rating":3},
        {"city":"dubai","rating":4},
        {"city":"bali","rating":5},
        {"city":"newyork","rating":6},
        {"city":"singapore","rating":7},
        {"city":"sydney","rating":8},
        {"city":"mubai","rating":9},
        {"city":"rome","rating":10}
         ]
        }

# %%
destination_cities_rating
# Out:
# {'destinations': [{'city': 'paris', 'rating': 1},
#   {'city': 'tokyo', 'rating': 2},
#   {'city': 'london', 'rating': 3},
#   {'city': 'dubai', 'rating': 4},
#   {'city': 'bali', 'rating': 5},
#   {'city': 'newyork', 'rating': 6},
#   {'city': 'singapore', 'rating': 7},
#   {'city': 'sydney', 'rating': 8},
#   {'city': 'mubai', 'rating': 9},
#   {'city': 'rome', 'rating': 10}]}

# %%
print(" rating 3 city name is",{"city":"london","rating":3} )
# Out:
#  rating 3 city name is {'city': 'london', 'rating': 3}

# %%
print({"city":"london","rating":3})
# Out:
# {'city': 'london', 'rating': 3}
