# %%
father="jayapaul"

# %%
father
# Out:
# 'jayapaul'

# %%
print("my father name is",father)
# Out:
# my father name is jayapaul

# %%
type(father)
# Out:
# str

# %%
mother="rangasarojini"

# %%
mother
# Out:
# 'rangasarojini'

# %%
print("my mother name is",mother)
# Out:
# my mother name is rangasarojini

# %%
type(mother)
# Out:
# str

# %%
older_sister="rajakumari"

# %%
older_sister
# Out:
# 'rajakumari'

# %%
print("my older sister name is",older_sister)
# Out:
# my older sister name is rajakumari

# %%
type(older_sister)
# Out:
# str

# %%
brother="sunil raju"

# %%
brother
# Out:
# 'sunil raju'

# %%
print("my brother name is",brother)
# Out:
# my brother name is sunil raju

# %%
type(brother)
# Out:
# str

# %%
sister="salomi"

# %%
sister
# Out:
# 'salomi'

# %%
print("my sister name is",sister)
# Out:
# my sister name is salomi

# %%
type(sister)
# Out:
# str

# %%
sister_in_law="meghana"

# %%
sister_in_law
# Out:
# 'meghana'

# %%
print("my sister in law name is",sister_in_law)
# Out:
# my sister in law name is meghana

# %%
type(sister_in_law)
# Out:
# str

# %%
nephew="yona"

# %%
nephew
# Out:
# 'yona'

# %%
print("my nephew name is",nephew)
# Out:
# my nephew name is yona

# %%
type(nephew)
# Out:
# str

# %%
niece="mahima jayasri"

# %%
niece
# Out:
# 'mahima jayasri'

# %%
print("my niece name is",niece)
# Out:
# my niece name is mahima jayasri

# %%
type(niece)
# Out:
# str

# %%
myself="sowjanya"

# %%
myself
# Out:
# 'sowjanya'

# %%
print("my name is",myself)
# Out:
# my name is sowjanya

# %%
type(myself)
# Out:
# str

# %%
myhusband="anilkumar"

# %%
myhusband
# Out:
# 'anilkumar'

# %%
print("my husband name is",myhusband)
# Out:
# my husband name is anilkumar

# %%
type(myhusband)
# Out:
# str
