# %%
friend_1="prasanna"

# %%
friend_1
# Out:
# 'prasanna'

# %%
print("the friend name is",friend_1)
# Out:
# the friend name is prasanna

# %%
type(friend_1)
# Out:
# str

# %%
friend_2="jhansi"

# %%
friend_2
# Out:
# 'jhansi'

# %%
print("the friend name is",friend_2)
# Out:
# the friend name is jhansi

# %%
type(friend_2)
# Out:
# str

# %%
friend_3="supraja"

# %%
friend_3
# Out:
# 'supraja'

# %%
print("the friend name is",friend_3)
# Out:
# the friend name is supraja

# %%
type(friend_3)
# Out:
# str

# %%
friend_4="srilakshmi"

# %%
friend_4
# Out:
# 'srilakshmi'

# %%
print("the friend name is",friend_4)
# Out:
# the friend name is srilakshmi

# %%
type(friend_4)
# Out:
# str

# %%
friend_5="sandhya"

# %%
friend_5
# Out:
# 'sandhya'

# %%
print("the friend name is",friend_5)
# Out:
# the friend name is sandhya

# %%
type(friend_5)
# Out:
# str

# %%
friend_6="nandhini"

# %%
friend_6
# Out:
# 'nandhini'

# %%
print("the friend name is",friend_6)
# Out:
# the friend name is nandhini

# %%
type(friend_6)
# Out:
# str

# %%
friend_7="anusha"

# %%
friend_7
# Out:
# 'anusha'

# %%
print("the friend name is",friend_7)
# Out:
# the friend name is anusha

# %%
type(friend_7)
# Out:
# str

# %%
friend_8="bindhu"

# %%
friend_8
# Out:
# 'bindhu'

# %%
print("the friend name is",friend_8)
# Out:
# the friend name is bindhu

# %%
type(friend_8)
# Out:
# str

# %%
friend_9="pavan"

# %%
friend_9
# Out:
# 'pavan'

# %%
print("the friend name is",friend_9)
# Out:
# the friend name is pavan

# %%
type(friend_9)
# Out:
# str

# %%
friend_10="phani"

# %%
friend_10
# Out:
# 'phani'

# %%
print("the friend name is",friend_10)
# Out:
# the friend name is phani

# %%
type(friend_10)
# Out:
# str
