# %%
colour_1="purple"

# %%
colour_1
# Out:
# 'purple'

# %%
print("the colour name is",colour_1)
# Out:
# the colour name is purple

# %%
type(colour_1)
# Out:
# str

# %%
colour_2="white"

# %%
colour_2
# Out:
# 'white'

# %%
print("the colour name is",colour_2)
# Out:
# the colour name is white

# %%
type(colour_2)
# Out:
# str

# %%
colour_3="brown"

# %%
colour_3
# Out:
# 'brown'

# %%
print("the colour name is",colour_3)
# Out:
# the colour name is brown

# %%
type(colour_3)
# Out:
# str

# %%
indigo_4="indigo"

# %%
indigo_4
# Out:
# 'indigo'

# %%
print("the colour name is",colour_4)
# Out:
# the colour name is indigo

# %%
type(indigo_4)
# Out:
# str

# %%
colour_5="yellow"

# %%
colour_5
# Out:
# 'yellow'

# %%
print("the colour name is",colour_5)
# Out:
# the colour name is yellow

# %%
type(colour_5)
# Out:
# str

# %%
colour_6="black"

# %%
colour_6
# Out:
# 'black'

# %%
print("the colour name is",colour_6)
# Out:
# the colour name is black

# %%
type(colour_6)
# Out:
# str

# %%
colour_7="marroon"

# %%
colour_7
# Out:
# 'marroon'

# %%
print("the colour name is",colour_7)
# Out:
# the colour name is marroon

# %%
type(colour_7)
# Out:
# str

# %%
colour_8="green"

# %%
colour_8
# Out:
# 'green'

# %%
print("the colour name is",colour_8)
# Out:
# the colour name is green

# %%
type(colour_8)
# Out:
# str

# %%
colour_9="navyblue"

# %%
colour_9
# Out:
# 'navyblue'

# %%
print("the colour name is",colour_9)
# Out:
# the colour name is navyblue

# %%
type(colour_9)
# Out:
# str

# %%
colour_10="orange"

# %%
colour_10
# Out:
# 'orange'

# %%
print("the colour name is",colour_10)
# Out:
# the colour name is orange

# %%
type(colour_10)
# Out:
# str
