# %%
city_1="bengaluru"

# %%
city_1
# Out:
# 'bengaluru'

# %%
print("the city name is",city_1)
# Out:
# the city name is bengaluru

# %%
type(city_1)
# Out:
# str

# %%
city_2="mumbai"

# %%
city_2
# Out:
# 'mumbai'

# %%
print("the city name is",city_2)
# Out:
# the city name is mumbai

# %%
type(city_2)
# Out:
# str

# %%
city_3="delhi"

# %%
city_3
# Out:
# 'delhi'

# %%
print("the city name is",city_3)
# Out:
# the city name is delhi

# %%
type(city_3)
# Out:
# str

# %%
city_4="hyedrabad"

# %%
city_4
# Out:
# 'hyedrabad'

# %%
print("the city name is",city_4)
# Out:
# the city name is hyedrabad

# %%
type(city_4)
# Out:
# str

# %%
city_5="chennai"

# %%
city_5
# Out:
# 'chennai'

# %%
print("the city name is",city_5)
# Out:
# the city name is chennai

# %%
type(city_5)
# Out:
# str

# %%
city_6="ahmedabad"

# %%
city_6
# Out:
# 'ahmedabad'

# %%
print("the city name is",city_6)
# Out:
# the city name is ahmedabad

# %%
type(city_6)
# Out:
# str

# %%
city_7="pune"

# %%
city_7
# Out:
# 'pune'

# %%
print("the city name is",city_7)
# Out:
# the city name is pune

# %%
type(city_7)
# Out:
# str

# %%
city_8="kolkata"

# %%
city_8
# Out:
# 'kolkata'

# %%
print("the city name is",city_8)
# Out:
# the city name is kolkata

# %%
type(city_8)
# Out:
# str

# %%
city_9="surat"

# %%
city_9
# Out:
# 'surat'

# %%
print("the city name is",city_9)
# Out:
# the city name is surat

# %%
type(city_9)
# Out:
# str

# %%
city_10="jaipur"

# %%
city_10
# Out:
# 'jaipur'

# %%
print("the city name is",city_10)
# Out:
# the city name is jaipur

# %%
type(city_10)
# Out:
# str
