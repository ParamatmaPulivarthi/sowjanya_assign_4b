# %%
game_1="cricket"

# %%
game_1
# Out:
# 'cricket'

# %%
print("the game name is",game_1)
# Out:
# the game name is cricket

# %%
type(game_1)
# Out:
# str

# %%
game_2="badminton"

# %%
game_2
# Out:
# 'badminton'

# %%
print("the game name is",game_2)
# Out:
# the game name is badminton

# %%
type(game_2)
# Out:
# str

# %%
game_3="football"

# %%
game_3
# Out:
# 'football'

# %%
print("the game name is",game_3)
# Out:
# the game name is football

# %%
type(game_3)
# Out:
# str

# %%
game_4="archery"

# %%
game_4
# Out:
# 'archery'

# %%
print("the game name is",game_4)
# Out:
# the game name is archery

# %%
type(game_4)
# Out:
# str

# %%
game_5="boxing"

# %%
game_5
# Out:
# 'boxing'

# %%
print("the game name is",game_5)
# Out:
# the game name is boxing

# %%
type(game_5)
# Out:
# str

# %%
game_6="hockey"

# %%
game_6
# Out:
# 'hockey'

# %%
print("the game name is",game_6)
# Out:
# the game name is hockey

# %%
type(game_6)
# Out:
# str

# %%
game_7="coco"

# %%
game_7
# Out:
# 'coco'

# %%
print("the game name is",game_7)
# Out:
# the game name is coco

# %%
type(game_7)
# Out:
# str

# %%
game_8="basketball"

# %%
game_8
# Out:
# 'basketball'

# %%
print("the game name is",game_8)
# Out:
# the game name is basketball

# %%
type(game_8)
# Out:
# str

# %%
game_9="chess"

# %%
game_9
# Out:
# 'chess'

# %%
print("the game name is",game_9)
# Out:
# the game name is chess

# %%
type(game_9)
# Out:
# str

# %%
game_10="tennis"

# %%
game_10
# Out:
# 'tennis'

# %%
print("the game name is",game_10)
# Out:
# the game name is tennis

# %%
type(game_10)
# Out:
# str
