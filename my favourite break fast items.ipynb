# %%
# print my favoourite breakfast item

# %%
breakfast_items=["upma","dosa","idly","puri","punugulu","roti","chapathi","parota","mysoorbaji","minapabaji"]

# %%
breakfast_items[7]
# Out:
# 'parota'

# %%
print("my favourite break fast item is",breakfast_items[7])
# Out:
# my favourite break fast item is parota
