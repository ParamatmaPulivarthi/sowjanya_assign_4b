# %%
# this is a duplicates remove bollywood heros names program

# %%
bollywood_heros=["sharukkhan","salmankhan","salmankhan","amirkhan","HrithikRoshan","AmithabhBachchan","AkshayKumar","amirkhan"]

# %%
bollywood_heros
# Out:
# ['sharukkhan',
#  'salmankhan',
#  'salmankhan',
#  'amirkhan',
#  'HrithikRoshan',
#  'AmithabhBachchan',
#  'AkshayKumar',
#  'amirkhan']

# %%
duplicates remove

# %%
bollywood_heros_v1=set(bollywood_heros)

# %%
bollywood_heros_v1
# Out:
# {'AkshayKumar',
#  'AmithabhBachchan',
#  'HrithikRoshan',
#  'amirkhan',
#  'salmankhan',
#  'sharukkhan'}
