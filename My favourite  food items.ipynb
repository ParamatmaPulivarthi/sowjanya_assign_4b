# %%
food_item_1="chicken biryani"

# %%
food_item_1
# Out:
# 'chicken biryani'

# %%
print("the food item name is",food_item_1)
# Out:
# the food item name is chicken biryani

# %%
type(food_item_1)
# Out:
# str

# %%
food_item_2="prawns curry"

# %%
food_item_2
# Out:
# 'prawns curry'

# %%
print("the food item name is",food_item_2)
# Out:
# the food item name is prawns curry

# %%
type(food_item_2)
# Out:
# str

# %%
food_item_3="fish fry"

# %%
food_item_3
# Out:
# 'fish fry'

# %%
print("the food item name is",food_item_3)
# Out:
# the food item name is fish fry

# %%
type(food_item_3)
# Out:
# str

# %%
food_item_4="potato fry curry"

# %%
food_item_4
# Out:
# 'potato fry curry'

# %%
print("the food item name is",food_item_4)
# Out:
# the food item name is potato fry curry

# %%
type(food_item_4)
# Out:
# str

# %%
food_item_5="mutton kheema"

# %%
food_item_5
# Out:
# 'mutton kheema'

# %%
print("the food item name is",food_item_5)
# Out:
# the food item name is mutton kheema

# %%
type(food_item_5)
# Out:
# str

# %%
food_item_6="coconut rice"

# %%
food_item_6
# Out:
# 'coconut rice'

# %%
print("the food item name is",food_item_6)
# Out:
# the food item name is coconut rice

# %%
type(food_item_6)
# Out:
# str

# %%
food_item_7="parota"

# %%
food_item_7
# Out:
# 'parota'

# %%
print("the food item name is",food_item_7)
# Out:
# the food item name is parota

# %%
type(food_item_7)
# Out:
# str

# %%
food_item_8="noodles"

# %%
food_item_8
# Out:
# 'noodles'

# %%
print("the food item name is",food_item_8)
# Out:
# the food item name is noodles

# %%
type(food_item_8)
# Out:
# str

# %%
food_item_9="chicken manchurian"

# %%
food_item_9
# Out:
# 'chicken manchurian'

# %%
print("the food item name is",food_item_9)
# Out:
# the food item name is chicken manchurian

# %%
type(food_item_9)
# Out:
# str

# %%
food_item_10="lemon rice"

# %%
food_item_10
# Out:
# 'lemon rice'

# %%
print("the food item name is",food_item_10)
# Out:
# the food item name is lemon rice

# %%
type(food_item_10)
# Out:
# str
