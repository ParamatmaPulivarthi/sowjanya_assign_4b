# %%
friend_names_tenth=["prsanna","jhansi","supraja","srilakshmi","sandhya","nandhini","anusha","bindhu","pavan","phani"]

# %%
friend_names_tenth
# Out:
# ['prsanna',
#  'jhansi',
#  'supraja',
#  'srilakshmi',
#  'sandhya',
#  'nandhini',
#  'anusha',
#  'bindhu',
#  'pavan',
#  'phani']

# %%
print(friend_names_tenth)
# Out:
# ['prsanna', 'jhansi', 'supraja', 'srilakshmi', 'sandhya', 'nandhini', 'anusha', 'bindhu', 'pavan', 'phani']

# %%
type(friend_names_tenth)
# Out:
# list

# %%
silicing---->
        <------

# %%
friend_names_tenth[0]
# Out:
# 'prsanna'

# %%
friend_names_tenth[1]
# Out:
# 'jhansi'

# %%
friend_names_tenth[2]
# Out:
# 'supraja'

# %%
friend_names_tenth[3]
# Out:
# 'srilakshmi'

# %%
friend_names_tenth[4]
# Out:
# 'sandhya'

# %%
friend_names_tenth[5]
# Out:
# 'nandhini'

# %%
friend_names_tenth[6]
# Out:
# 'anusha'

# %%
friend_names_tenth[7]
# Out:
# 'bindhu'

# %%
friend_names_tenth[8]
# Out:
# 'pavan'

# %%
friend_names_tenth[9]
# Out:
# 'phani'

# %%
friend_names_tenth[-1]
# Out:
# 'phani'

# %%
friend_names_tenth[-2]
# Out:
# 'pavan'

# %%
friend_names_tenth[-3]
# Out:
# 'bindhu'

# %%
friend_names_tenth[-4]
# Out:
# 'anusha'

# %%
friend_names_tenth[-5]
# Out:
# 'nandhini'

# %%
friend_names_tenth[-6]
# Out:
# 'sandhya'

# %%
friend_names_tenth[-7]
# Out:
# 'srilakshmi'

# %%
friend_names_tenth[-8]
# Out:
# 'supraja'

# %%
friend_names_tenth[-9]
# Out:
# 'jhansi'

# %%
friend_names_tenth[-10]
# Out:
# 'prsanna'

# %%
friend_names_tenth[0]
# Out:
# 'prsanna'

# %%
starting position:ending position values

# %%
friend_names_tenth
# Out:
# ['prsanna',
#  'jhansi',
#  'supraja',
#  'srilakshmi',
#  'sandhya',
#  'nandhini',
#  'anusha',
#  'bindhu',
#  'pavan',
#  'phani']

# %%
friend_names_tenth[3:5]
# Out:
# ['srilakshmi', 'sandhya']

# %%
friend_names_tenth[1:4]
# Out:
# ['jhansi', 'supraja', 'srilakshmi']

# %%
friend_names_tenth[6:]
# Out:
# ['anusha', 'bindhu', 'pavan', 'phani']

# %%
friend_names_tenth[-5:-1]
# Out:
# ['nandhini', 'anusha', 'bindhu', 'pavan']
